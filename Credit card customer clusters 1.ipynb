# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")
# Read data set
A = pd.read_csv("CC GENERAL.csv")
A.head(4)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# ...

# %%
A.shape
# Out:
# (8950, 18)

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
A.isnull().mean()*100
# Out:
# CUST_ID                             0.000000
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %%
for i in A.columns:
    print(i,"===============>",len(A[i].unique()))
# Out:
# CUST_ID ===============> 8950
# BALANCE ===============> 8871
# BALANCE_FREQUENCY ===============> 43
# PURCHASES ===============> 6203
# ONEOFF_PURCHASES ===============> 4014
# INSTALLMENTS_PURCHASES ===============> 4452
# CASH_ADVANCE ===============> 4323
# PURCHASES_FREQUENCY ===============> 47
# ONEOFF_PURCHASES_FREQUENCY ===============> 47
# PURCHASES_INSTALLMENTS_FREQUENCY ===============> 47
# CASH_ADVANCE_FREQUENCY ===============> 54
# CASH_ADVANCE_TRX ===============> 65
# PURCHASES_TRX ===============> 173
# CREDIT_LIMIT ===============> 206
# PAYMENTS ===============> 8711
# MINIMUM_PAYMENTS ===============> 8637
# PRC_FULL_PAYMENT ===============> 47
# TENURE ===============> 7

# %%
A.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
A.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# # Data Preprocessing

# %%
A.drop("CUST_ID",axis=1)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
A.dropna(subset=['CREDIT_LIMIT'], inplace=True)

# %%
A['MINIMUM_PAYMENTS'].fillna(A['MINIMUM_PAYMENTS'].median(), inplace=True)

# %%
sns.displot(A['MINIMUM_PAYMENTS'])

# %%
plt.figure(figsize=(20,35))
for i, col in enumerate(A.columns):
    if A[col].dtypes != "object":
        place = plt.subplot(9,2, i + 1)
        sns.kdeplot(A[col], ax= place)
        plt.xlabel(col)

# %%
A.shape
# Out:
# (8949, 18)

# %%
(A.skew().sort_values()>0.5).index
# Out:
# Index(['TENURE', 'BALANCE_FREQUENCY', 'PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CREDIT_LIMIT',
#        'ONEOFF_PURCHASES_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'PRC_FULL_PAYMENT', 'BALANCE', 'PURCHASES_TRX', 'CASH_ADVANCE',
#        'CASH_ADVANCE_TRX', 'PAYMENTS', 'INSTALLMENTS_PURCHASES', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'MINIMUM_PAYMENTS'],
#       dtype='object')

# %%
con=[]
cat=[]
for i in A.columns:
    if A[i].dtypes=="object":
        cat.append(i)
    else:
        con.append(i)

# %%
con
# Out:
# ['BALANCE',
#  'BALANCE_FREQUENCY',
#  'PURCHASES',
#  'ONEOFF_PURCHASES',
#  'INSTALLMENTS_PURCHASES',
#  'CASH_ADVANCE',
#  'PURCHASES_FREQUENCY',
#  'ONEOFF_PURCHASES_FREQUENCY',
#  'PURCHASES_INSTALLMENTS_FREQUENCY',
#  'CASH_ADVANCE_FREQUENCY',
#  'CASH_ADVANCE_TRX',
#  'PURCHASES_TRX',
#  'CREDIT_LIMIT',
#  'PAYMENTS',
#  'MINIMUM_PAYMENTS',
#  'PRC_FULL_PAYMENT',
#  'TENURE']

# %%
cols = ['BALANCE', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'ONEOFF_PURCHASES_FREQUENCY','PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT']
for col in cols:
    A[col] = np.log(1+A[col])

# %%
w= A['TENURE'].apply(np.log)

# %%
w.skew()
# Out:
# -3.201423112866178

# %%
A.skew().sort_values()
# Out:
# TENURE                             -2.944788
# BALANCE_FREQUENCY                  -2.024193
# PAYMENTS                           -1.779084
# BALANCE                            -0.861421
# CREDIT_LIMIT                       -0.101438
# INSTALLMENTS_PURCHASES             -0.025206
# PURCHASES_TRX                       0.032536
# PURCHASES_FREQUENCY                 0.059970
# ONEOFF_PURCHASES                    0.185650
# CASH_ADVANCE                        0.262755
# MINIMUM_PAYMENTS                    0.271330
# PURCHASES_INSTALLMENTS_FREQUENCY    0.373434
# CASH_ADVANCE_TRX                    0.940039
# ONEOFF_PURCHASES_FREQUENCY          1.290460
# PRC_FULL_PAYMENT                    1.745872
# CASH_ADVANCE_FREQUENCY              1.828644
# PURCHASES                           8.143969
# dtype: float64

# %%
plt.figure(figsize=(20,35))
for i, col in enumerate(cols):
    place = plt.subplot(9,2, i + 1)
    sns.kdeplot(A[col], ax= place)
    plt.xlabel(col)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(A.corr(), annot= True, cmap="YlGnBu")
plt.show()

# %%
def preprocessing(df):
    import pandas as pd
    cat = []
    con = []
    for i in df.columns:
        if(df[i].dtypes == "object"):
            cat.append(i)
        else:
            con.append(i)
    X1 = pd.get_dummies(df[cat])
    from sklearn.preprocessing import StandardScaler
    ss = StandardScaler()
    X2 = pd.DataFrame(ss.fit_transform(df[con]),columns=con)
    X3 = X2.join(X1)
    return X3

# %%
X = preprocessing(A)

# %%
from sklearn.decomposition import PCA
A = A.drop("CUST_ID",axis = 1)
pca = PCA(n_components=0.95)
X_red = pca.fit_transform(A)

# %%
from sklearn.cluster import KMeans
wcss = []
k = range(1,10,1)
for i in range(1,10,1):
    km = KMeans(n_clusters=i)
    model = km.fit(X_red)
    wcss.append(model.inertia_)

# %%
import matplotlib.pyplot as plt
plt.scatter(k,wcss,c="red")
plt.plot(k,wcss,c="blue")
plt.xlabel("Number of clusters - K")
plt.ylabel("Within Clusters Sum of Squares")
plt.title("Elbow Curve")
plt.xticks(range(1,11,1))
plt.show()

# %%
km = KMeans(n_clusters=2)
model = km.fit(X_red)

# %%
A['cluster_id'] = model.labels_

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=A, x='ONEOFF_PURCHASES', y='PURCHASES', hue='cluster_id')
plt.title('Distribution of clusters based on One off purchases and total purchases')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=A, x='CREDIT_LIMIT', y='PURCHASES', hue='cluster_id')
plt.title('Distribution of clusters based on Credit limit and total purchases')
plt.show()

# %%
km = KMeans(n_clusters=3)
model = km.fit(X_red)

# %%
A['cluster_id'] = model.labels_

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=A, x='ONEOFF_PURCHASES', y='PURCHASES', hue='cluster_id')
plt.title('Distribution of clusters based on One off purchases and total purchases')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=A, x='CREDIT_LIMIT', y='PURCHASES', hue='cluster_id')
plt.title('Distribution of clusters based on Credit limit and total purchases')
plt.show()
